# %% [markdown]
# <a href="https://colab.research.google.com/github/crossleyd/idiap/blob/main/Idiap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![An image](https://raw.githubusercontent.com/idiap/coqui-ai-TTS/main/images/coqui-log-green-TTS.png)
# #[Click here to go to the original project I used.](https://github.com/idiap/coqui-ai-TTS)
# # Coqui-ai Text-to-Speech:
# # Run this in Google Colab, GPU mode only.
# [Google Colab](https://colab.research.google.com)

# %% [markdown]
# A program to turn chosen text into a selected voice, using Coqui-ai, modified by D.Crossley, A.D.2025.

# %%
# Copy the compiled code of the package into here.
# !git clone https://github.com/crossleyd/coquiCompiled.git
# Out:
# Cloning into 'coquiCompiled'...
# remote: Enumerating objects: 770, done.
# remote: Counting objects: 100% (770/770), done.
# remote: Compressing objects: 100% (649/649), done.
# remote: Total 770 (delta 72), reused 766 (delta 72), pack-reused 0 (from 0)
# Receiving objects: 100% (770/770), 22.26 MiB | 38.90 MiB/s, done.
# Resolving deltas: 100% (72/72), done.

# %%
# Change to the directory it's in.
# %cd coquiCompiled
# Out:
# /content/coquiCompiled

# %%
# Install it as a Python module.
# !python -m pip install -e .
# Out:
# Obtaining file:///content/coquiCompiled
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 26.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 77.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 70.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
#!pip install coqui-tts  # This is an alternative way of bringing in the code from the official package.
# However, I've found that this way, you need to restart it after it cannot find the modules.

# %%
try:
  import torch
  from TTS.api import TTS
except:  # Stop here if an error is thrown and display a message to restart.
  print('Stopping RUNTIME! Colab needs to restart.  Runtime -> Run All again.')
  exit()
import os
from google.colab import files
import IPython

# %% [markdown]
# #`1.   Enter your text in the box`
#
# #`2.   Click the button to upload your voice`

# %% [markdown]
# <h1 style="color:blue;">Scroll down</h1>

# %% [markdown]
# ##*Don't forget to accept the Coqui Licence agreement if prompted.*

# %%
textToSpeak = input("Enter Text:") # Enter the text to convert
# Out:
# Enter Text:I will burn China to the ground.

# %%
# Open a file upload box for user uploading custom voice.
targetDirectory = "/content/tortoise/voices"

uploadedFiles = files.upload(targetDirectory) # Get a reference to the uploaded file.

# Get the name of the first file uploaded.
upLoadedFileName = next(iter(uploadedFiles))
print("First file you uploaded is: ")

print(upLoadedFileName)

print("Using that as your custom voice.")

# The rest of the code is mostly from the Coqui-ai project.  Link given at the top of the page.

# Get device
device = "cuda" if torch.cuda.is_available() else "cpu"

tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)

tts.tts_to_file(
  text = textToSpeak,
  speaker_wav = upLoadedFileName,
  language = "en",
  file_path = "../output.wav"
)
# Out:
#      <input type="file" id="files-cd9ed22e-d8cd-488b-8cbc-4e8a0de46249" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd9ed22e-d8cd-488b-8cbc-4e8a0de46249">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Result will appear below as output.wav

# %%
IPython.display.Audio(filename='../output.wav', rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %cd ..
# Out:
# /content

# %%
# %ls
# Out:
# coquiCompiled/  output.wav  sample_data/  tortoise/
